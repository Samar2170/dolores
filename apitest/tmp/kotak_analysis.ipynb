# %%
import json
import os

# %%
file = open("../../__reference_files__/KOTAKBANK_indiasm_2026-08-27T00-08-43.json", "rb")
data = json.load(file)
file.close()

# %%
data.keys()
# Out:
# dict_keys(['companyName', 'industry', 'companyProfile', 'currentPrice', 'stockTechnicalData', 'percentChange', 'yearHigh', 'yearLow', 'financials', 'keyMetrics', 'futureExpiryDates', 'futureOverviewData', 'initialStockFinancialData', 'analystView', 'recosBar', 'riskMeter', 'shareholding', 'stockCorporateActionData', 'stockDetailsReusableData', 'stockFinancialData', 'recentNews'])

# %%
len(data['financials'])
# Out:
# 15

# %%
for i in data['financials']:
    print(i)
# Out:
# {'stockFinancialMap': {'CAS': [{'displayName': 'Issuance( Retirement)of Debt Net ', 'key': 'Issuance(Retirement)ofDebtNet', 'value': '-2228.50', 'qoQComp': None, 'yqoQComp': None}, {'displayName': 'Net Changein Cash ', 'key': 'NetChangeinCash', 'value': '23029.35', 'qoQComp': None, 'yqoQComp': None}, {'displayName': 'Cash Taxes Paid ', 'key': 'CashTaxesPaid', 'value': '6433.33', 'qoQComp': None, 'yqoQComp': None}, {'displayName': 'Net Income/ Starting Line ', 'key': 'NetIncome/StartingLine', 'value': '19180.63', 'qoQComp': None, 'yqoQComp': None}, {'displayName': 'Total Cash Dividends Paid ', 'key': 'TotalCashDividendsPaid', 'value': '-497.10', 'qoQComp': None, 'yqoQComp': None}, {'displayName': 'Changesin Working Capital ', 'key': 'ChangesinWorkingCapital', 'value': '14601.70', 'qoQComp': None, 'yqoQComp': None}, {'displayName': 'Cashfrom Operating Activities ', 'key': 'CashfromOperatingActivities', 'value': '41726.51', 'qoQComp': None, 'yqoQComp': None}, {'displayName': 'Cashfrom F
# ...

# %%
for i in data['financials']:
    print(i.keys())
# Out:
# dict_keys(['stockFinancialMap', 'FiscalYear', 'EndDate', 'Type', 'StatementDate', 'fiscalPeriodNumber'])
# dict_keys(['stockFinancialMap', 'FiscalYear', 'EndDate', 'Type', 'StatementDate', 'fiscalPeriodNumber'])
# dict_keys(['stockFinancialMap', 'FiscalYear', 'EndDate', 'Type', 'StatementDate', 'fiscalPeriodNumber'])
# dict_keys(['stockFinancialMap', 'FiscalYear', 'EndDate', 'Type', 'StatementDate', 'fiscalPeriodNumber'])
# dict_keys(['stockFinancialMap', 'FiscalYear', 'EndDate', 'Type', 'StatementDate', 'fiscalPeriodNumber'])
# dict_keys(['stockFinancialMap', 'FiscalYear', 'EndDate', 'Type', 'StatementDate', 'fiscalPeriodNumber'])
# dict_keys(['stockFinancialMap', 'FiscalYear', 'EndDate', 'Type', 'StatementDate', 'fiscalPeriodNumber'])
# dict_keys(['stockFinancialMap', 'FiscalYear', 'EndDate', 'Type', 'StatementDate', 'fiscalPeriodNumber'])
# dict_keys(['stockFinancialMap', 'FiscalYear', 'EndDate', 'Type', 'StatementDate', 'fiscalPeriodNumber'])
# ...

# %%
for i in data['stockTechnicalData']:
    print(i.keys())
# Out:
# dict_keys(['days', 'bsePrice', 'nsePrice'])
# dict_keys(['days', 'bsePrice', 'nsePrice'])
# dict_keys(['days', 'bsePrice', 'nsePrice'])
# dict_keys(['days', 'bsePrice', 'nsePrice'])
# dict_keys(['days', 'bsePrice', 'nsePrice'])
# dict_keys(['days', 'bsePrice', 'nsePrice'])
