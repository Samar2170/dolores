# %%
import os
import pandas as pd

# %%
dfs = pd.read_html('../__reference_files__/tickertape_kotak.html')
# Out:
# /tmp/ipykernel_344171/2783475673.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html('../__reference_files__/tickertape_kotak.html')
# /home/samar/.pyenv/versions/conceptvenv/lib/python3.10/site-packages/pandas/io/html.py:666: MarkupResemblesLocatorWarning: The input passed in on this line looks more like a filename than HTML or XML.
#
# If you meant to use Beautiful Soup to parse the contents of a file on disk, then something has gone wrong. You should open the file first, using code like this:
#
#     filehandle = open(your filename)
#
# You can then feed the open filehandle into Beautiful Soup instead of using the filename.
#
# ...

# %%
# %pip install beautifulsoup4
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.9/109.9 kB 3.8 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 23.3.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
